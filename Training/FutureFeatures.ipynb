# %%
from funcs import *
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = load_DF('https://raw.githubusercontent.com/mohannashahrad/Borealis_AI_Plant_Tree_Project/main/Final_Data/final_data2.csv')
df = df.iloc[: , 1:]
display(df.head())
# Out:
#    Time Country Name  Land Area (m2)  Agriculture Land (m2)  Forest Land (m2)  \
# 0  2001  Afghanistan        652860.0               377530.0           12084.4
# 1  2002  Afghanistan        652860.0               377530.0           12084.4
# 2  2003  Afghanistan        652860.0               379100.0           12084.4
# 3  2004  Afghanistan        652860.0               379110.0           12084.4
# 4  2005  Afghanistan        652860.0               379100.0           12084.4
#
#    Population  Pop Growth (%)  Urban Pop (%)     GDP (US$)  GDP Growth (%)  \
# 0  21606992.0        3.902805         22.169           NaN             NaN
# 1  22600774.0        4.496719         22.261  4.055180e+09             NaN
# 2  23680871.0        4.668344         22.353  4.515559e+09        8.832278
# 3  24726689.0        4.321560         22.500  5.226779e+09        1.414118
# 4  25654274.0        3.682700         22.703  6.209138e+09       11.229715
#
#    Forest Rents (% GDP)  Coal Rents (% GDP)  Oil Rents (% GDP)  \
# 0                   NaN                 NaN                NaN
# 1              0.958004            0.004341           0.029101
# 2              0.664331            0.007422           0.026686
# 3              0.387787            0.016455           0.025399
# 4              0.332205            0.010904           0.025973
#
#    CO2 Emission (kt)  GHG Emision (CO2 eqv)  Tree Loss (ha)
# 0              810.0                13490.0       88.092712
# 1             1100.0                16090.0      178.640364
# 2             1350.0                16780.0      244.336255
# 3             1130.0                16520.0      201.444959
# 4             1640.0                17400.0      235.956834

# %%
predict(df, 'Time', 'Country Name', 'Afghanistan', ['Population', 'GDP (US$)'])
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 14.
# component     Population     GDP (US$)
# time
# 2021-01-01  3.984142e+07  2.466502e+10
# 2022-01-01  4.071723e+07  2.543321e+10
# 2023-01-01  4.158707e+07  2.618335e+10
# 2024-01-01  4.247365e+07  2.691574e+10
# 2025-01-01  4.338674e+07  2.872043e+10
